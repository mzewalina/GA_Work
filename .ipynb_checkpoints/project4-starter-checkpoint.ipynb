# %% [markdown]
# # Project 4
#
# In this project, you will summarize and present your analysis from Projects 1-3.

# %% [markdown]
# ### Intro: Write a problem Statement/ Specific Aim for this project

# %% [markdown]
# Answer: look at who gets admitted given gpa, gre scores, and prestige of former university

# %% [markdown]
# ### Dataset:  Write up a description of your data and any cleaning that was completed

# %% [markdown]
# Answer: categorical admit status (0,1), removed NAs

# %% [markdown]
# ### Demo: Provide a table that explains the data by admission status

# %% [markdown]
# Mean (STD) or counts by admission status for each variable
#
# | Not Admitted | Admitted
# ---| ---|---
# GPA | 3.35(.37)  | 3.49(.37)
# GRE |573(116) | 618(109)
# Prestige 1 | 33 (54%) | 28 (46%)
# Prestige 2 | 53 (36) | 95 (64%)
# Prestige 3 |28 (23%) | 93 (77%)
# Prestige 4 |12 (18%) | 55 (82%)

# %%
import pandas as pd
import numpy as np
df_raw = pd.read_csv("../assets/admissions.csv")
df = df_raw.dropna() 
dfa=df.groupby('admit')
df = df.join(pd.get_dummies(df['prestige'],prefix='prestige'))
#df = df.drop('prestige',1)
#print dfa
print dfa.describe()

# %%
##it was easier to just paste the values in.  I need to play with tables more to figoure out how to format everything properly,
#after more than an hour of not being able to get a "(" placed in, i decided to cut and paste from other tables.  
print dfa['prestige'].value_counts()
print df['admit'].value_counts()
# Out:
# admit  prestige
# 0      2.0         95
#        3.0         93
#        4.0         55
#        1.0         28
# 1      2.0         53
#        1.0         33
#        3.0         28
#        4.0         12
# Name: prestige, dtype: int64
# 0    271
# 1    126
# Name: admit, dtype: int64

# %% [markdown]
# ### Methods: Write up the methods used in your analysis)

# %% [markdown]
# Answer: We did basic summaries, in project 2 i did many plots, we did a logit regression

# %% [markdown]
# ### Results: Write up your results

# %% [markdown]
# Answer: admission status is dependent on GRE, GPA and prestige of university status.  The relationship is made clearer in the graphs below.

# %% [markdown]
# ### Visuals: Provide a table or visualization of these results

# %%
from IPython.display import Image
Image("gpa.png")

# %%
Image("gre.png")

# %% [markdown]
# ### Discussion: Write up your discussion and future steps

# %%
Admission is dependent on GRE, prestige, and GPA.  Even perfect GPA/GRE scores dont make up for going to a bad school unfortunately.

next steps-- I wouldnt know, but id be interested in demographics of who goes to a prestige 1 vs 2,3,4 schools. 
Maybe this is where socioeconomic mobility stops for many people--

looking at the kids with perfect GRE scores but a low admit rate is depressing-- id want to know what beyond prestige 
are holding these kids back.

# %% [markdown]
# Answer:
